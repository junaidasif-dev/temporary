# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\student\Downloads\ttrain.csv')

# %%
sns.boxplot(x=data['Survived'], y=data['Age'])
plt.show()

# %%
sns.boxplot(x=data['Gender'], y=data['Age'])
plt.show()

# %%
sns.histplot(data['Age'])
plt.show()

# %%
sns.histplot(data['Pclass'])
plt.show()

# %%
plt.scatter(x=data['Age'], y=data['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
print(data['Embarked'].value_counts())
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
table1=pd.crosstab(data['Pclass'], data['Embarked'], margins=True, margins_name='Sum')
print(table1)
# Out:
# Embarked    C   Q    S  Sum
# Pclass
# 1          85   2  127  214
# 2          17   3  164  184
# 3          66  72  353  491
# Sum       168  77  644  889

# %%
table1=pd.crosstab(data['Pclass'], data['Gender'], margins=True, margins_name='Sum')
print(table1)
# Out:
# Gender  female  male  Sum
# Pclass
# 1           94   122  216
# 2           76   108  184
# 3          144   347  491
# Sum        314   577  891

# %%
table1=pd.crosstab(data['Gender'], data['Embarked'], margins=True, margins_name='Sum')
print(table1)
# Out:
# Embarked    C   Q    S  Sum
# Gender
# female     73  36  203  312
# male       95  41  441  577
# Sum       168  77  644  889

# %%
plt.hist(data['Age'], bins=8, histtype= 'bar')
plt.show()

# %%
data['Age'].skew()
# Out:
# 0.38910778230082704

# %%
plt.hist(data['Fare'], bins=8, histtype= 'bar')
plt.show()

# %%
print(data['Fare'].skew())
plt.figure(figsize=(10,10))
sns.boxplot(data['Fare'])
plt.show()
# Out:
# 4.787316519674893

# %%
sns.countplot(x = data['Parch'])
plt.show()

# %%
sns.countplot(x = data['Survived'])
plt.show()

# %%
sns.countplot(x = data['Gender'])
plt.show()

# %%
sns.countplot(x = data['Pclass'])
plt.show()

# %%
sns.boxplot(x=data['Survived'], y=data['Fare'])
plt.show()

# %%
sns.countplot(x=data['Gender'], hue = data['Survived'])
plt.show()

# %%
sns.countplot(x=data['Pclass'], hue = data['Survived'])
plt.show()

# %%
sns.countplot(x=data['Embarked'], hue = data['Survived'])
plt.show()

# %%
sns.countplot(x=data['Embarked'])
plt.show()

# %%
sns.countplot(x=data['Parch'], hue = data['Survived'])
plt.show()

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
